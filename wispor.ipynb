# %% [markdown]
# <a href="https://colab.research.google.com/github/AdarshPal740/new/blob/main/wispor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/openai/whisper.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-6ot7v_5d
#   Running command git clone -q https://github.com/openai/whisper.git /tmp/pip-req-build-6ot7v_5d
# ...
#      |████████████████████████████████| 5.3 MB 25.4 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 50.3 MB/s
# ...
#      |████████████████████████████████| 163 kB 64.3 MB/s
# ...
#   Created wheel for whisper: filename=whisper-1.0-py3-none-any.whl size=1175217 sha256=671cafd61f668a0ee4a27508510a44ddefe93cd4356e95f4733c0314b4ccb751
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_n0r503g/wheels/16/15/89/1c7bb31bd0006793a95549d04785121a8a36daad9158e1e43a
# Successfully built whisper
# ...

# %%
import whisper

# %%
model=whisper.load_model("base")
# Out:
# 100%|████████████████████████████████████████| 139M/139M [00:00<00:00, 176MiB/s]

# %%
out=model.transcribe("/content/mujhko-itna-bataye-koi-kaise-tujhse-dil-na-lagaye-koi-music-57668-58230-58231.mp3",language="en")

# %%
out
# Out:
# {'text': ' How did you find someone with your heart? Lord, make yourself a man, and make yourself a man, and make yourself a man, and make yourself a man, and make yourself a man, and make yourself a man, and make yourself a man, and make yourself a man, and make yourself a man, and make yourself a man, in your mind, in your life, in your life, Shiba, do you know the meaning of this? But...',
#  'segments': [{'id': 0,
#    'seek': 0,
#    'start': 0.0,
#    'end': 8.0,
#    'text': ' How did you find someone with your heart?',
#    'tokens': [50364,
#     1012,
#     630,
#     291,
#     915,
#     1580,
#     365,
#     428,
#     1917,
#     30,
#     50764,
#     50914,
#     3257,
#     11,
#     652,
#     1803,
#     257,
#     587,
#     11,
#     51164,
#     51164,
#     293,
#     652,
#     1803,
#     257,
#     587,
#     11,
#     51264,
#     51264,
#     293,
#     652,
#     1803,
#     257,
#     587,
#     11,
#     51414,
#     51414,
#     293,
#     652,
# ...
